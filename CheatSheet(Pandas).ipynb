# %% [markdown]
# <a href="https://colab.research.google.com/github/salonisngh/cognitive-computing/blob/main/CheatSheet(Pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data={
    'Name':["alan","Alice","brent"],
    'Age':[23,21,24]
}

df=pd.DataFrame(data)

# %% [markdown]
# Reading and Writing

# %%
df1=pd.read_csv('/traffic_data.csv')
df.to_csv('file.csv',index=False)

# %% [markdown]
# Inspecting data

# %%
df1.head() #first 5 rows
# Out:
#       location day_of_week  vehicle_count  avg_speed  \
# 0    Hill Road      Monday            525      42.25
# 1    Tech Park    Thursday            532      20.89
# 2    Tech Park    Thursday            725      33.48
# 3  City Center      Sunday            844      23.07
# 4     Greenway      Friday            627      49.19
#
#                                incident_notes weather ref_code
# 0      Accident near crosswalk, slow movement  Cloudy     FD0T
# 1      Accident near crosswalk, slow movement  Cloudy     SAHX
# 2  Construction causing blockage in left lane   Clear     1FPK
# 3                Diversion due to local event   Clear     MMJB
# 4                Diversion due to local event   Clear     T3W5

# %%
df1.tail()
# Out:
#          location day_of_week  vehicle_count  avg_speed  \
# 10      Hill Road      Friday            938      46.93
# 11    Sector 21-A      Sunday            612      24.59
# 12  West Junction      Friday            511      40.41
# 13    Sector 21-A    Saturday            769      49.16
# 14    City Center   Wednesday            665      36.18
#
#                                       incident_notes weather ref_code
# 10                      Diversion due to local event   Rainy     H9SD
# 11                                No issues reported   Foggy     VNVQ
# 12  Heavy congestion from 8am–9am. Parking overflow.   Rainy     1MKF
# 13                                No issues reported   Clear     5KXV
# 14        Light jam near roundabout due to breakdown   Rainy     REN9

# %%
df1.shape #dimension of row and columns
# Out:
# (15, 7)

# %%
df1.columns
# Out:
# Index(['location', 'day_of_week', 'vehicle_count', 'avg_speed',
#        'incident_notes', 'weather', 'ref_code'],
#       dtype='object')

# %%
df1.info() #Summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   location        15 non-null     object
#  1   day_of_week     15 non-null     object
#  2   vehicle_count   15 non-null     int64
#  3   avg_speed       15 non-null     float64
#  4   incident_notes  15 non-null     object
#  5   weather         15 non-null     object
#  6   ref_code        15 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 972.0+ bytes

# %%
df1.describe() #Stats Summary
# Out:
#        vehicle_count  avg_speed
# count      15.000000   15.00000
# mean      700.800000   34.72000
# std       164.457637   10.35626
# min       511.000000   20.89000
# 25%       564.000000   24.73500
# 50%       665.000000   36.18000
# 75%       806.500000   42.06000
# max      1046.000000   49.19000

# %%
df1.dtypes #data types
# Out:
# location           object
# day_of_week        object
# vehicle_count       int64
# avg_speed         float64
# incident_notes     object
# weather            object
# ref_code           object
# dtype: object

# %% [markdown]
# Selecting Data

# %%
df1['location'] #Single columns
df1[['location','weather']] #Multiple columns
df1.iloc[[0,2],:] #row by index
# Out:
#     location day_of_week  vehicle_count  avg_speed  \
# 0  Hill Road      Monday            525      42.25
# 2  Tech Park    Thursday            725      33.48
#
#                                incident_notes weather ref_code
# 0      Accident near crosswalk, slow movement  Cloudy     FD0T
# 2  Construction causing blockage in left lane   Clear     1FPK

# %%
df1.loc[0] #row by label
df1[0:3] #rows slicing
# Out:
#     location day_of_week  vehicle_count  avg_speed  \
# 0  Hill Road      Monday            525      42.25
# 1  Tech Park    Thursday            532      20.89
# 2  Tech Park    Thursday            725      33.48
#
#                                incident_notes weather ref_code
# 0      Accident near crosswalk, slow movement  Cloudy     FD0T
# 1      Accident near crosswalk, slow movement  Cloudy     SAHX
# 2  Construction causing blockage in left lane   Clear     1FPK

# %% [markdown]
# FILTERING DATA

# %%
df1[df1['vehicle_count']<600] #conditon
df1[df1['vehicle_count']<600 & (df1['day_of_week']=='thursday')]
# Out:
# Empty DataFrame
# Columns: [location, day_of_week, vehicle_count, avg_speed, incident_notes, weather, ref_code]
# Index: []

# %% [markdown]
# Sorting and Renaming

# %%
df.sort_values('Age')
df.rename(columns={'Age':'Months'})
# Out:
#     Name  Months
# 0   alan      23
# 1  Alice      21
# 2  brent      24

# %% [markdown]
# ADDING/UPDATING

# %%
df['retire'] =df['Age']+10 #New Column
df.loc[0,'Age']=37 #Update Value

# %%
df['Age'].mean()
# Out:
# np.float64(22.666666666666668)
